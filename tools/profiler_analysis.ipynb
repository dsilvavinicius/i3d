# %%
import pstats
from pstats import SortKey

# %%
profile_out = pstats.Stats("sdfniters_armadillo_100epochs.prof")

# %%
profile_out.sort_stats(SortKey.CUMULATIVE).print_stats()
# Out:
# Wed Feb  8 12:21:00 2023    sdfniters_armadillo_100epochs.prof
#
#          7200019 function calls (7128665 primitive calls) in 79.134 seconds
#
#    Ordered by: cumulative time
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#    2573/1    0.053    0.000   79.136   79.136 {built-in method builtins.exec}
#         1    0.212    0.212   79.136   79.136 experiment_scripts/sdf_for_n_iters.py:1(<module>)
#      1730    0.019    0.000   36.158    0.021 /home/gschardong/.pyenv/versions/i3d/lib/python3.10/site-packages/torch/optim/optimizer.py:135(wrapper)
#      1730    0.014    0.000   36.064    0.021 /home/gschardong/.pyenv/versions/i3d/lib/python3.10/site-packages/torch/optim/optimizer.py:19(_use_grad)
#      1730    0.052    0.000   36.042    0.021 /home/gschardong/.pyenv/versions/i3d/lib/python3.10/site-packages/torch/optim/adam.py:168(step)
# ...
